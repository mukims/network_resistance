# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sc
import networkx as ntx
from numpy.random import choice
import scipy.sparse.linalg as spla

# %%
def E0(layers):
    m1=[]
    for j in np.arange(0,8*layers,8):
        m1.append([(i+j,i+1+j) for i in range(7)])
    return np.array(m1).reshape(-1,2)
def E1(layers):
    m2=[]
    for j in np.arange(0,8*(layers-1),8):
        m2.append(np.array([((j+i,j+7+i),(j+i,j+7+2+i)) for i in np.arange(1,7,2)]))
    m2=np.array(m2).reshape(-1,2)
    return m2
def E2(layers):
    m3=[]
    m3.append([(j+7,j+14) for j in np.arange(0,8*(layers-1),8)])
    m3=np.array(m3).reshape(-1,2)
    return m3
def E3(layers):
    m4=[]
    m4.append([(8*layers+1,i) for i in np.arange(0,7,2)])
    return np.array(m4).reshape(-1,2)


def E4(layers):
    m5=[]
    m5.append([(layers*8,i) for i in np.arange((layers-1)*8+1,layers*8,2)])
    return np.array(m5).reshape(-1,2)

# %%
def create_graph(layers,seed):
    np.random.seed(seed)
    number_of_indices = 8*layers
    G = ntx.Graph()
    #G.add_nodes_from(range(8 * layers))
    e0 = E0(layers)
    e1 = E1(layers)
    e2 = E2(layers)
    e3 = E3(layers)
    e4 = E4(layers)
    G.add_edges_from(e0)
    G.add_edges_from(e1)
    G.add_edges_from(e2)
  #  G.add_edges_from(e3)
  #  G.add_edges_from(e4)
#    G.add_edges_from(((0,11),(6,20)))
    return G

# %%
def create_3d_graph(layers, seed, depth):
    G_2d = create_graph(layers, seed)
    G_3d = ntx.Graph()

    max_index = max(G_2d.nodes)

    for z in range(depth):
        for node in G_2d.nodes:
            G_3d.add_node((node, z))
        for edge in G_2d.edges:
            G_3d.add_edge((edge[0], z), (edge[1], z))

        # Connect layers vertically (with no even-to-even connections)
        if z < depth - 1:
            for node in G_2d.nodes:
                if node % 2 == 1 and node < max_index:  # Only consider odd nodes
                    for neighbor in G_2d.neighbors(node):
                        if neighbor % 2 == 0:
                            G_3d.add_edge((node, z), (neighbor, z + 1))

    return G_3d

# %%
def generate_random_values(mean, std, seed, num_edges):
    np.random.seed(seed)
    return np.abs(np.random.normal(mean, std, num_edges))

# %%
def matrix_interactions(layers,depth,h):
    grid = create_3d_graph(layers,1,depth)
    num_edges = grid.number_of_edges()
    nodes = grid.number_of_nodes()
#    print(nodes)
    cap_values = 1*np.exp(h)*generate_random_values(1, 0.0001, 1, num_edges)
    
    adjM = sc.lil_matrix((nodes, nodes))
    xxx = list(grid.edges())
    interactions = 1/cap_values
    
    for edge_idx, (i, j) in enumerate(xxx):
        interaction_value = interactions[edge_idx]
        adjM[i, j] = interaction_value
        adjM[j, i] = interaction_value
        
    adjM.setdiag(-1*adjM.sum(axis=1).A1 - 0.0001)
    
    MI = spla.inv(-1*adjM.tocsc())  # Using inv for CSC matrices
    
    return MI,nodes

# %%
n,m = matrix_interactions(4,40,1)

# %%
m
# Out:
# 1280

# %%
def R(a,b,h):
    MI,nodes = matrix_interactions(4,40,h)
    return MI[a, a] + MI[b, b] - MI[a,b] - MI[b, a]

# %%
j1=[R(0,1279,h) for h in np.arange(0.01,10,0.01)]

# %%
plt.loglog(j1)

# %%
jin=[R(0,31,h) for h in np.arange(0.01,1,0.01)]

# %%
plt.loglog(jin)

# %%
def visualize_3d_graph(G):
    pos = nx.spring_layout(G, dim=3, seed=42)  # 3D layout
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    nx.draw(G, pos, ax=ax, with_labels=True, node_size=100, font_size=8)
    ax.set_axis_off()  # Optional: Remove axis lines for cleaner look
    plt.show()

# %%
visualize_3d_graph(create_3d_graph(2, 1,4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 visualize_3d_graph(create_3d_graph(2, 1,4))
#
# Cell In[118], line 5, in visualize_3d_graph(G)
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(111, projection='3d')
# ----> 5 nx.draw(G, pos, ax=ax, with_labels=True, node_size=100, font_size=8)
#       6 ax.set_axis_off()  # Optional: Remove axis lines for cleaner look
#       7 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:896, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     894 # Draw the edges
#     895 if use_linecollection:
# --> 896     edge_viz_obj = _draw_networkx_edges_line_collection()
#     897     # Make sure selfloop edges are also drawn
#     898     selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:738, in draw_networkx_edges.<locals>._draw_networkx_edges_line_collection()
#     737 def _draw_networkx_edges_line_collection():
# --> 738     edge_collection = mpl.collections.LineCollection(
#     739         edge_pos,
#     740         colors=edge_color,
#     741         linewidths=width,
#     742         antialiaseds=(1,),
#     743         linestyle=style,
#     744         alpha=alpha,
#     745     )
#     746     edge_collection.set_cmap(edge_cmap)
#     747     edge_collection.set_clim(edge_vmin, edge_vmax)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:1441, in LineCollection.__init__(self, segments, zorder, **kwargs)
#    1437 kwargs.setdefault('facecolors', 'none')
#    1438 super().__init__(
#    1439     zorder=zorder,
#    1440     **kwargs)
# -> 1441 self.set_segments(segments)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:1447, in LineCollection.set_segments(self, segments)
#    1444 if segments is None:
#    1445     return
# -> 1447 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
#    1448                else mpath.Path(np.asarray(seg, float))
#    1449                for seg in segments]
#    1450 self.stale = True
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:1448, in <listcomp>(.0)
#    1444 if segments is None:
#    1445     return
#    1447 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
# -> 1448                else mpath.Path(np.asarray(seg, float))
#    1449                for seg in segments]
#    1450 self.stale = True
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#     133     codes = np.asarray(codes, self.code_type)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/_api/__init__.py:161, in check_shape(shape, **kwargs)
#     158 if len(shape) == 1:
#     159     text_shape += ","
# --> 161 raise ValueError(
#     162     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     163     f"but your input has shape {v.shape}"
#     164 )
#
# ValueError: 'vertices' must be 2D with shape (N, 2), but your input has shape (2, 3)
